# %%
import sys
sys.path.append("/home/chase/projects/net-queue/src/python")
from qnetWithDrivers import *

# %%
servers = range(3,6)
service_rates = 1.0 * np.array(range(3,6))

rates = 80
utilizationStats = np.zeros((rates,3))
averageWaitTime = np.zeros((rates,2))

data_dict = {}

for numServers in servers:
    data_dict[numServers] = {}
    for service_rate in service_rates:
        paramInst = parameters("QNetparams.txt")
        data_dict[numServers][service_rate] = {}
        data_dict[numServers][service_rate]["utilization"] = utilizationStats
        data_dict[numServers][service_rate]["waitTime"] = averageWaitTime
        for jj in range(rates):
            paramInst.lambd = paramInst.lambd + float(jj)/100
            paramInst.mu = service_rate
            paramInst.num_spots = numServers

            QNet = blockfaceNet(paramInst, ["utilization"])
            for bf in QNet.bface.keys():
                QNet.bface[bf].arrival_rate = QNet.params.lambd
                QNet.bface[bf].service_rate = service_rate
                QNet.bface[bf].num_parking_spots = numServers
                QNet.bface[bf].spots = np.array([0.0 for j in range(int(QNet.params.num_spots))])

            while QNet.timer < QNet.params.simulation_time:
                #find block numbers of blocks with <=0.0 time till next arrival
                #can use itertools.compress on new arrivals list comprehension
                currently_arriving_blocks = [ j for j, x in enumerate(list(QNet.new_arrivals)) if x < QNet.params.time_resolution ]
                if len(currently_arriving_blocks) > 0:
                #give arriving blocks new arrivals
                #prioritize exogenous arrivals
                    for i in currently_arriving_blocks:
                        blockindex = QNet.injection_map[i]
                        next_arrival_time = np.random.exponential(QNet.bface[blockindex].arrival_rate)
                        QNet.new_arrivals[i] = next_arrival_time 
                        QNet.bface[blockindex].exogenous += 1
                        QNet.carIndex += 1
                        QNet.cars[QNet.carIndex] = car(QNet.carIndex)
                        #try to park, otherwise, drive somewhere else
                        QNet.park(blockindex, QNet.carIndex)
    
                for origin in QNet.bface.keys():
                    #Checking for any drivers arriving at other blocks based on travel time in street buffer
                    #have to loop through every block? Yes, if I care about street direction
                    for dest in range(len(QNet.streets[origin])):
                        #for each possible destination index, get the block index, neighbors is list of block indexs connected to origin
                        #but dest is local index of street connected to origin to save space, 
                        #e.g. block 2 to block 3 is connected by block 2's street 1
                        destblock = QNet.bface[origin].neighbors[dest]
                        #at least first driver needs to be arriving
                        if len(QNet.streets[origin][dest]) > 0 and QNet.streets[origin][dest][0] < QNet.params.time_resolution:
                            #first driver in list will always be closest to 0 unless drive times vary
                            #>>>>>THIS WON'T WORK IF DRIVE TIMES ARE NOT CONSTANT<<<<<<<<<<<
                            for driver in QNet.streets[origin][dest]:
                                #could be more than one arriving
                                while QNet.streets[origin][dest][0] < QNet.params.time_resolution:
                                    carIndex = QNet.streetsDrivers[origin][dest][0]
                                    QNet.park(destblock, carIndex)
                                    #Get rid of first driver, go back up and check if next driver is also arriving
                                    QNet.streets[origin][dest].pop(0)
                                    QNet.streetsDrivers[origin][dest].pop(0)
                                    if len(QNet.streets[origin][dest]) == 0:
                                        break
    
                #step simulation forward and collect any flagged global stats
                QNet.step_time()

            print("\n==Results==")
            for i in QNet.bface.keys():
                if i in QNet.injection_map.values():
                    print("block number " + str(i) + " (injector):\n\ttotal arrivals: " + str(QNet.bface[i].total))
                    print("\tinjected: " + str(QNet.bface[i].exogenous))
                else:
                    print("block number " + str(i) + ":\n\ttotal arrivals: " + str(QNet.bface[i].total))
                print("\tparked: " + str(QNet.bface[i].served))
                print("\taverage utilization: " + str(float(sum(QNet.bface[i].utilization))/float(len(QNet.bface[i].utilization)) * 100.0) + "%")
                data_dict[numServers][service_rate]["utilization"][jj,i+1] = float(sum(QNet.bface[i].utilization))/float(len(QNet.bface[i].utilization))
    
            #calculating average wait time
            total = 0.0
            numCars = float(len(QNet.cars.keys()))
            for carInd in QNet.cars.keys():
                total += QNet.cars[carInd].totalDriveTime
            averageWait = total/numCars
            print("average wait time: " + str(averageWait) + "\n")
        
            data_dict[numServers][service_rate]["waitTime"][jj,1] = averageWait
            data_dict[numServers][service_rate]["waitTime"][jj,0] = QNet.params.lambd
            data_dict[numServers][service_rate]["utilization"][jj,0] = QNet.params.lambd
# Out:
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 132938
# 	injected: 1263
# 	parked: 1007
# 	average utilization: 93.9393939394%
# block number 1 (injector):
# 	total arrivals: 132916
# 	injected: 1275
# 	parked: 995
# 	average utilization: 93.9393939394%
# average wait time: 103.960598897
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 118373
# 	injected: 1237
# 	parked: 968
# 	average utilization: 93.9393939394%
# block number 1 (injector):
# 	total arrivals: 118297
# 	injected: 1197
# 	parked: 990
# 	average utilization: 93.9393939394%
# average wait time: 96.430566968
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 140515
# 	injected: 1241
# 	parked: 1010
# 	average utilization: 93.9393939394%
# block number 1 (injector):
# 	total arrivals: 140470
# 	injected: 1279
# 	parked: 963
# 	average utilization: 93.9393939394%
# average wait time: 110.719047619
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 103785
# 	injected: 1215
# 	parked: 1033
# 	average utilization: 90.9090909091%
# block number 1 (injector):
# 	total arrivals: 103759
# 	injected: 1164
# 	parked: 1017
# 	average utilization: 90.9090909091%
# average wait time: 86.3783102144
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 84889
# 	injected: 1130
# 	parked: 1016
# 	average utilization: 93.9393939394%
# block number 1 (injector):
# 	total arrivals: 84853
# 	injected: 1157
# 	parked: 945
# 	average utilization: 93.9393939394%
# average wait time: 73.362920857
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 62715
# 	injected: 1082
# 	parked: 998
# 	average utilization: 87.8787878788%
# block number 1 (injector):
# 	total arrivals: 62679
# 	injected: 1074
# 	parked: 933
# 	average utilization: 93.9393939394%
# average wait time: 57.2648423006
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 16963
# 	injected: 980
# 	parked: 965
# 	average utilization: 81.8181818182%
# block number 1 (injector):
# 	total arrivals: 16949
# 	injected: 959
# 	parked: 941
# 	average utilization: 84.8484848485%
# average wait time: 16.506446622
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 5630
# 	injected: 929
# 	parked: 886
# 	average utilization: 84.8484848485%
# block number 1 (injector):
# 	total arrivals: 5610
# 	injected: 880
# 	parked: 901
# 	average utilization: 90.9090909091%
# average wait time: 5.22553897181
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 4602
# 	injected: 929
# 	parked: 919
# 	average utilization: 81.8181818182%
# block number 1 (injector):
# 	total arrivals: 4510
# 	injected: 842
# 	parked: 833
# 	average utilization: 90.9090909091%
# average wait time: 4.15584415584
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 2720
# 	injected: 830
# 	parked: 815
# 	average utilization: 78.7878787879%
# block number 1 (injector):
# 	total arrivals: 2708
# 	injected: 803
# 	parked: 818
# 	average utilization: 72.7272727273%
# average wait time: 2.32394366197
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 2564
# 	injected: 732
# 	parked: 759
# 	average utilization: 66.6666666667%
# block number 1 (injector):
# 	total arrivals: 2540
# 	injected: 735
# 	parked: 708
# 	average utilization: 63.6363636364%
# average wait time: 2.47920927062
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 1369
# 	injected: 663
# 	parked: 668
# 	average utilization: 63.6363636364%
# block number 1 (injector):
# 	total arrivals: 1382
# 	injected: 681
# 	parked: 675
# 	average utilization: 51.5151515152%
# average wait time: 1.04761904762
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 1085
# 	injected: 602
# 	parked: 603
# 	average utilization: 51.5151515152%
# block number 1 (injector):
# 	total arrivals: 1086
# 	injected: 604
# 	parked: 603
# 	average utilization: 54.5454545455%
# average wait time: 0.800165837479
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 1029
# 	injected: 605
# 	parked: 595
# 	average utilization: 54.5454545455%
# block number 1 (injector):
# 	total arrivals: 1050
# 	injected: 616
# 	parked: 625
# 	average utilization: 69.696969697%
# average wait time: 0.703521703522
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 673
# 	injected: 503
# 	parked: 507
# 	average utilization: 42.4242424242%
# block number 1 (injector):
# 	total arrivals: 700
# 	injected: 534
# 	parked: 530
# 	average utilization: 42.4242424242%
# average wait time: 0.324011571842
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 644
# 	injected: 485
# 	parked: 480
# 	average utilization: 57.5757575758%
# block number 1 (injector):
# 	total arrivals: 662
# 	injected: 498
# 	parked: 502
# 	average utilization: 51.5151515152%
# average wait time: 0.329603255341
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 534
# 	injected: 458
# 	parked: 450
# 	average utilization: 48.4848484848%
# block number 1 (injector):
# 	total arrivals: 535
# 	injected: 455
# 	parked: 459
# 	average utilization: 39.3939393939%
# average wait time: 0.175246440307
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 528
# 	injected: 441
# 	parked: 447
# 	average utilization: 30.303030303%
# block number 1 (injector):
# 	total arrivals: 511
# 	injected: 430
# 	parked: 424
# 	average utilization: 24.2424242424%
# average wait time: 0.192881745121
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 451
# 	injected: 378
# 	parked: 391
# 	average utilization: 36.3636363636%
# block number 1 (injector):
# 	total arrivals: 465
# 	injected: 405
# 	parked: 392
# 	average utilization: 21.2121212121%
# average wait time: 0.169859514687
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 410
# 	injected: 366
# 	parked: 378
# 	average utilization: 18.1818181818%
# block number 1 (injector):
# 	total arrivals: 406
# 	injected: 374
# 	parked: 362
# 	average utilization: 36.3636363636%
# average wait time: 0.102702702703
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 406
# 	injected: 350
# 	parked: 336
# 	average utilization: 33.3333333333%
# block number 1 (injector):
# 	total arrivals: 406
# 	injected: 336
# 	parked: 350
# 	average utilization: 45.4545454545%
# average wait time: 0.183673469388
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 368
# 	injected: 320
# 	parked: 331
# 	average utilization: 45.4545454545%
# block number 1 (injector):
# 	total arrivals: 386
# 	injected: 349
# 	parked: 338
# 	average utilization: 21.2121212121%
# average wait time: 0.127055306428
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 324
# 	injected: 310
# 	parked: 309
# 	average utilization: 39.3939393939%
# block number 1 (injector):
# 	total arrivals: 295
# 	injected: 280
# 	parked: 281
# 	average utilization: 33.3333333333%
# average wait time: 0.0491525423729
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 307
# 	injected: 291
# 	parked: 292
# 	average utilization: 9.09090909091%
# block number 1 (injector):
# 	total arrivals: 292
# 	injected: 277
# 	parked: 276
# 	average utilization: 30.303030303%
# average wait time: 0.0545774647887
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 258
# 	injected: 238
# 	parked: 254
# 	average utilization: 15.1515151515%
# block number 1 (injector):
# 	total arrivals: 314
# 	injected: 310
# 	parked: 294
# 	average utilization: 36.3636363636%
# average wait time: 0.043795620438
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 227
# 	injected: 224
# 	parked: 218
# 	average utilization: 12.1212121212%
# block number 1 (injector):
# 	total arrivals: 271
# 	injected: 262
# 	parked: 268
# 	average utilization: 27.2727272727%
# average wait time: 0.0246913580247
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 253
# 	injected: 243
# 	parked: 245
# 	average utilization: 39.3939393939%
# block number 1 (injector):
# 	total arrivals: 234
# 	injected: 226
# 	parked: 224
# 	average utilization: 15.1515151515%
# average wait time: 0.0383795309168
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 223
# 	injected: 219
# 	parked: 213
# 	average utilization: 18.1818181818%
# block number 1 (injector):
# 	total arrivals: 211
# 	injected: 201
# 	parked: 207
# 	average utilization: 9.09090909091%
# average wait time: 0.0333333333333
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 195
# 	injected: 188
# 	parked: 193
# 	average utilization: 12.1212121212%
# block number 1 (injector):
# 	total arrivals: 223
# 	injected: 221
# 	parked: 214
# 	average utilization: 27.2727272727%
# average wait time: 0.0268948655257
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 207
# 	injected: 203
# 	parked: 202
# 	average utilization: 21.2121212121%
# block number 1 (injector):
# 	total arrivals: 195
# 	injected: 190
# 	parked: 191
# 	average utilization: 15.1515151515%
# average wait time: 0.0229007633588
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 186
# 	injected: 184
# 	parked: 182
# 	average utilization: 21.2121212121%
# block number 1 (injector):
# 	total arrivals: 217
# 	injected: 213
# 	parked: 215
# 	average utilization: 15.1515151515%
# average wait time: 0.0151133501259
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 180
# 	injected: 177
# 	parked: 175
# 	average utilization: 30.303030303%
# block number 1 (injector):
# 	total arrivals: 201
# 	injected: 196
# 	parked: 198
# 	average utilization: 18.1818181818%
# average wait time: 0.0214477211796
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 158
# 	injected: 158
# 	parked: 158
# 	average utilization: 12.1212121212%
# block number 1 (injector):
# 	total arrivals: 161
# 	injected: 161
# 	parked: 161
# 	average utilization: 15.1515151515%
# average wait time: 0.0
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 146
# 	injected: 144
# 	parked: 145
# 	average utilization: 24.2424242424%
# block number 1 (injector):
# 	total arrivals: 162
# 	injected: 161
# 	parked: 160
# 	average utilization: 24.2424242424%
# average wait time: 0.00983606557377
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 133
# 	injected: 133
# 	parked: 133
# 	average utilization: 24.2424242424%
# block number 1 (injector):
# 	total arrivals: 136
# 	injected: 136
# 	parked: 136
# 	average utilization: 21.2121212121%
# average wait time: 0.0
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 127
# 	injected: 125
# 	parked: 124
# 	average utilization: 18.1818181818%
# block number 1 (injector):
# 	total arrivals: 174
# 	injected: 171
# 	parked: 172
# 	average utilization: 12.1212121212%
# average wait time: 0.0168918918919
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 144
# 	injected: 143
# 	parked: 144
# 	average utilization: 15.1515151515%
# block number 1 (injector):
# 	total arrivals: 125
# 	injected: 125
# 	parked: 124
# 	average utilization: 9.09090909091%
# average wait time: 0.00373134328358
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 135
# 	injected: 132
# 	parked: 135
# 	average utilization: 18.1818181818%
# block number 1 (injector):
# 	total arrivals: 119
# 	injected: 119
# 	parked: 116
# 	average utilization: 15.1515151515%
# average wait time: 0.0119521912351
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 136
# 	injected: 136
# 	parked: 134
# 	average utilization: 15.1515151515%
# block number 1 (injector):
# 	total arrivals: 119
# 	injected: 117
# 	parked: 119
# 	average utilization: 6.06060606061%
# average wait time: 0.00790513833992
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 113
# 	injected: 112
# 	parked: 112
# 	average utilization: 21.2121212121%
# block number 1 (injector):
# 	total arrivals: 109
# 	injected: 108
# 	parked: 108
# 	average utilization: 6.06060606061%
# average wait time: 0.00909090909091
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 125
# 	injected: 125
# 	parked: 123
# 	average utilization: 12.1212121212%
# block number 1 (injector):
# 	total arrivals:
# 	average utilization: 1.81818181818%
# block number 1 (injector):
# 	total arrivals: 2
# 	injected: 2
# 	parked: 2
# 	average utilization: 3.63636363636%
# average wait time: 0.0
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 3
# 	injected: 3
# 	parked: 3
# 	average utilization: 3.63636363636%
# block number 1 (injector):
# 	total arrivals: 4
# 	injected: 4
# 	parked: 4
# 	average utilization: 1.81818181818%
# average wait time: 0.0
#
# 0% complete
# 10% complete
# 20% complete
# 30% complete
# 40% complete
# 50% complete
# 60% complete
# 70% complete
# 80% complete
# 90% complete
# 100% complete
# ==Results==
# block number 0 (injector):
# 	total arrivals: 3
# 	injected: 3
# 	parked: 3
# 	average utilization: 1.81818181818%
# block number 1 (injector):
# 	total arrivals: 6
# 	injected: 6
# 	parked: 6
# 	average utilization: 1.81818181818%
# average wait time: 0.0

# %%
data_dict[3].keys()
# Out:
# [3.0, 4.0, 5.0]

# %%
paramInst.lambd
# Out:
# 285.2

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.plot(averageWaitTime[:,0], averageWaitTime[:,1])
plt.title("2-bus average wait times as a function of arrival rate")
plt.xlabel("arrival rate")
plt.ylabel("average wait time")
plt.show()

# %%
rates = np.zeros((100,1))
for i in range(100):
    rates[i] = (QNet.params.lambd)-(utilizationStats[-i-1,0])/100.0
rates
# Out:
# array([[ 0.5 ],
#        [ 0.51],
#        [ 0.52],
#        [ 0.53],
#        [ 0.54],
#        [ 0.55],
#        [ 0.56],
#        [ 0.57],
#        [ 0.58],
#        [ 0.59],
#        [ 0.6 ],
#        [ 0.61],
#        [ 0.62],
#        [ 0.63],
#        [ 0.64],
#        [ 0.65],
#        [ 0.66],
#        [ 0.67],
#        [ 0.68],
#        [ 0.69],
#        [ 0.7 ],
#        [ 0.71],
#        [ 0.72],
#        [ 0.73],
#        [ 0.74],
#        [ 0.75],
#        [ 0.76],
#        [ 0.77],
#        [ 0.78],
#        [ 0.79],
#        [ 0.8 ],
#        [ 0.81],
#        [ 0.82],
#        [ 0.83],
#        [ 0.84],
#        [ 0.85],
#        [ 0.86],
#        [ 0.87],
#        [ 0.88],
#        [ 0.89],
#        [ 0.9 ],
#        [ 0.91],
#        [ 0.92],
#        [ 0.93],
#        [ 0.94],
#        [ 0.95],
#        [ 0.96],
#        [ 0.97],
#        [ 0.98],
#        [ 0.99],
#        [ 1.  ],
#        [ 1.01],
#        [ 1.02],
#        [ 1.03],
#        [ 1.04],
#        [ 1.05],
#        [ 1.06],
#        [ 1.07],
#        [ 1.08],
#        [ 1.09],
#        [ 1.1 ],
#        [ 1.11],
#        [ 1.12],
#        [ 1.13],
#        [ 1.14],
#        [ 1.15],
#        [ 1.16],
#        [ 1.17],
#        [ 1.18],
#        [ 1.19],
#        [ 1.2 ],
#        [ 1.21],
#        [ 1.22],
#        [ 1.23],
#        [ 1.24],
#        [ 1.25],
#        [ 1.26],
#        [ 1.27],
#        [ 1.28],
#        [ 1.29],
#        [ 1.3 ],
#        [ 1.31],
#        [ 1.32],
#        [ 1.33],
#        [ 1.34],
#        [ 1.35],
#        [ 1.36],
#        [ 1.37],
#        [ 1.38],
#        [ 1.39],
#        [ 1.4 ],
#        [ 1.41],
#        [ 1.42],
#        [ 1.43],
#        [ 1.44],
#        [ 1.45],
#        [ 1.46],
#        [ 1.47],
#        [ 1.48],
#        [ 1.49]])

# %%
rates
# Out:
# array([1, 1])
